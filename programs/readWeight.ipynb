# %%
import numpy as np

# 假设权重是32位的浮点数 (float32)，你可以根据实际情况修改数据类型
def read_weights(filename):
    with open(filename, 'rb') as f:
        # 读取所有数据，假设数据是 float32 类型
        data = np.fromfile(f, dtype=np.float32)
    return data

# 读取权重文件
weights = read_weights(r'C:\InDeutschland\202506Hackathon\hpmpc-cinephoto\nn\Pygeon\models\pretrained\vgg16_cifar_trained_party2.bin')
# weights = read_weights(r'C:\InDeutschland\202506Hackathon\hpmpc-cinephoto\nn\Pygeon\models\pretrained\vgg16_cifar_standard.bin')

# 打印一些权重数据
print(weights[:100])  # 打印前10个权重
# Out:
# [ 2.08994950e-38  1.25740454e-24 -3.57815732e+24  1.59477759e+15
#  -2.81295512e-15  1.05085588e-32 -4.20215458e+32 -4.85846439e-20
#   8.91009479e+19  2.82438015e+30 -1.48777468e-30 -3.80606015e-35
#   1.17887941e+35 -1.05767315e+37  3.80197340e-37 -1.95461552e-27
#   2.21610034e+27 -2.44432211e+35  1.84031891e-35  3.88318593e-32
#  -1.15592912e+32  3.62042189e-01 -1.24146500e+01  1.00577630e+37
#  -4.16913064e-37  4.42789652e-36 -1.01591500e+36  2.04758788e+35
#  -2.12773475e-35  1.03039193e-29 -4.33307952e+29 -1.67453688e-18
#   2.46584642e+18 -9.80676873e-08  4.54560960e+07  4.52874519e-22
#  -9.11737982e+21 -3.91297050e-07  1.13982830e+07 -1.99413943e+00
#   2.01172113e+00 -7.08710863e-29  6.32341164e+28 -3.26210960e-38
#   1.37172248e+38  2.06514862e+02 -2.16656663e-02 -1.29010956e+34
#   3.38514868e-34 -3.21764424e-17  1.32637962e+17  8.30651256e-19
#  -5.00205883e+18  3.55297032e+20 -1.21715709e-20  2.06358594e-29
# ...
